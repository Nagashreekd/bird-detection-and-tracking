# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/26 days/26days
# Out:
# /content/drive/MyDrive/26 days/26days

# %%
ls
# Out:
# data.yaml  README.roboflow.txt  train/

# %%
# %cd /content/drive/MyDrive/26 days/26days

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=640 batch=4 plots=True
# Out:
# /content/drive/MyDrive/26 days/26days
# ...
# 100% 21.5M/21.5M [00:00<00:00, 136MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    results.png		   val_batch0_pred.jpg
# confusion_matrix.png				    train_batch0.jpg	   val_batch1_labels.jpg
# events.out.tfevents.1699521514.7292c3077a18.1767.0  train_batch1.jpg	   val_batch1_pred.jpg
# F1_curve.png					    train_batch2175.jpg    val_batch2_labels.jpg
# P_curve.png					    train_batch2176.jpg    val_batch2_pred.jpg
# PR_curve.png					    train_batch2177.jpg    weights
# R_curve.png					    train_batch2.jpg
# results.csv					    val_batch0_labels.jpg

# %%
Image(filename='/content/drive/MyDrive/26 days/26days/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %%
Image(filename='runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# 2023-11-09 09:50:29.830165: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-09 09:50:29.830225: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-09 09:50:29.830264: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-09 09:50:29.839181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
